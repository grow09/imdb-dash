# %%
import pandas as pd
import pycountry
import time

def merge_movie_data():
    """Merge csv files."""
    start_time = time.time()

    # Load and filter title basics

    columns_to_load = ["tconst","originalTitle","titleType","startYear","runtimeMinutes","genres"]
    title_basics = pd.read_csv('assets/title.basics.csv', usecols=columns_to_load, engine='pyarrow')

    # Filter the DataFrame based on the `titleType` column
    title_basics_filtered = title_basics.query('titleType in ["movie", "tvSeries"]')

    print(f"time to load title basics: {time.time() - start_time:.2f} s")

    # Load and process IMDb movies
    imdb_movies = pd.read_csv('assets/imdb_movies.csv', usecols=['orig_title', 'overview', 'budget_x', 'revenue', 'country', 'genre', 'date_x'])
    imdb_movies['year_x'] = pd.to_datetime(imdb_movies['date_x'], errors='coerce').dt.year.astype(str)


    # Merge IMDb movies with filtered title basics
    merged_data = pd.merge(
        imdb_movies, title_basics_filtered,
        left_on=['orig_title', 'year_x'],
        right_on=['originalTitle', 'startYear'],
        how='left'
    )

    # Load title ratings and merge with existing data
    title_ratings = pd.read_csv('assets/title.ratings.csv')
    merged_data = pd.merge(
        merged_data, title_ratings,
        on='tconst',
        how='left'
    )

    # Remove duplicates based on 'tconst'
    merged_data = merged_data.drop_duplicates(subset='tconst')

    merged_data['year_x'] = pd.to_numeric(merged_data['year_x'], errors='coerce')

    # Example: Convert ISO-2 column to ISO-3
    merged_data['country_name'] = merged_data['country'].apply(iso2_to_country_name)

    # Drop rows where conversion failed (invalid ISO-2 codes)
    merged_data = merged_data.dropna(subset=['country_name'])
    merged_data = merged_data.dropna(subset=['titleType'])


    # Clean the genre column by splitting comma-separated genres and trimming whitespace
    merged_data['genre'] = merged_data['genre'].apply(
        lambda x: [genre.strip() for genre in x.split(',')] if isinstance(x, str) else (x if isinstance(x, list) else [])
    )

    # Drop rows with empty genres, if necessary
    merged_data = merged_data[merged_data['genre'].apply(lambda x: isinstance(x, list) and len(x) > 0)]

    print(f"time to run all: {time.time() - start_time:.2f} s")

    return merged_data


def iso2_to_country_name(iso2_code):
    try:
        # Convert ISO-2 to full country name using pycountry
        return pycountry.countries.get(alpha_2=iso2_code).name
    except AttributeError:
        return None  # Return None if the code is invalid or not found


# Example usage
if __name__ == "__main__":
    merged_data = merge_movie_data()
# Out:
# time to load title basics: 5.41 s
# time to run all: 6.39 s

# %%
display(merged_data)
# Out:
#             date_x                                            genre  \
# 0      03/02/2023                                   [Drama, Action]
# 1      12/15/2022              [Science Fiction, Adventure, Action]
# 2      04/05/2023   [Animation, Adventure, Family, Fantasy, Comedy]
# 4      03/17/2023                                          [Action]
# 5      02/23/2023                         [Thriller, Comedy, Crime]
# ...            ...                                              ...
# 10426  07/10/2008                                 [Comedy, Romance]
# 10428  10/07/1938                       [Mystery, Thriller, Comedy]
# 10429  12/28/2016                                           [Drama]
# 10430  08/24/1990                                          [Action]
# 10431  12/21/1990                        [Drama, Thriller, Romance]
#
#                                                 overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 4      Good-hearted teenager William always lived in ...
# 5      Inspired by a true story, an oddball group of ...
# ...                                                  ...
# 10426  Born in America and raised in an Indian ashram...
# 10428  On a train headed for England a group of trave...
# 10429  In 1979 Santa Barbara, California, Dorothea Fi...
# 10430  When DEA agents are taken captive by a ruthles...
# 10431  Barley Scott Blair, a Lisbon-based editor of R...
#
#                                     orig_title     budget_x       revenue  \
# 0                                    Creed III   75000000.0  2.716167e+08
# 1                     Avatar: The Way of Water  460000000.0  2.316795e+09
# 2                  The Super Mario Bros. Movie  100000000.0  7.244590e+08
# 4                                    Supercell   77000000.0  3.409420e+08
# 5                                 Cocaine Bear   35000000.0  8.000000e+07
# ...                                        ...          ...           ...
# 10426                            The Love Guru   62000000.0  4.015902e+07
# 10428                        The Lady Vanishes  132000000.0  5.637564e+08
# 10429                       20th Century Women    7000000.0  9.353729e+06
# 10430  Delta Force 2: The Colombian Connection    9145817.8  6.698361e+06
# 10431                         The Russia House   21800000.0  2.299799e+07
#
#       country  year_x      tconst                            originalTitle  \
# 0          AU    2023  tt11145118                                Creed III
# 1          AU    2022   tt1630029                 Avatar: The Way of Water
# 2          AU    2023   tt6718170              The Super Mario Bros. Movie
# 4          US    2023  tt10559102                                Supercell
# 5          AU    2023  tt14209916                             Cocaine Bear
# ...       ...     ...         ...                                      ...
# 10426      AU    2008   tt0811138                            The Love Guru
# 10428      GB    1938   tt0030341                        The Lady Vanishes
# 10429      US    2016   tt4385888                       20th Century Women
# 10430      US    1990   tt0099399  Delta Force 2: The Colombian Connection
# 10431      US    1990   tt0100530                         The Russia House
#
#       titleType startYear runtimeMinutes                      genres  \
# 0         movie      2023            116          Action,Drama,Sport
# 1         movie      2022            192    Action,Adventure,Fantasy
# 2         movie      2023             92  Adventure,Animation,Comedy
# 4         movie      2023            100      Action,Adventure,Drama
# 5         movie      2023             95       Comedy,Crime,Thriller
# ...         ...       ...            ...                         ...
# 10426     movie      2008             87        Comedy,Romance,Sport
# 10428     movie      1938             96            Mystery,Thriller
# 10429     movie      2016            119                Comedy,Drama
# 10430     movie      1990            111      Action,Adventure,Crime
# 10431     movie      1990            123      Drama,Romance,Thriller
#
#        averageRating  numVotes    country_name
# 0                6.7   98374.0       Australia
# 1                7.5  523442.0       Australia
# 2                7.0  258549.0       Australia
# 4                4.4    3555.0   United States
# 5                5.9  116631.0       Australia
# ...              ...       ...             ...
# 10426            3.8   55695.0       Australia
# 10428            7.7   58711.0  United Kingdom
# 10429            7.3   50706.0   United States
# 10430            4.9    8426.0   United States
# 10431            6.1   18469.0   United States
#
# [5365 rows x 17 columns]

# %%
df = pd.read_csv('./assets/merged_data.csv')


unique_title_types = df['country'].unique()
print(unique_title_types)
# Out:
# ['AU' 'US' 'GB' 'CL' 'DE' 'ES' 'FR' 'MX' 'GT' 'BR' 'ZA' 'NL' 'FI' 'ID'
#  'DK' 'JP' 'IE' 'BE' 'AR' 'PH' 'TR' 'IT' 'CA' 'CH' 'CN' 'PE' 'SG' 'PL'
#  'IN' 'GR' 'RU' 'TW' 'MY' 'MU' 'NO' 'UA' 'HK' 'SE' 'CO']

# %%
df = pd.read_csv('./assets/merged_data.csv')

display(df['tconst'].unique())
# Out:
#                                    orig_title  \
# 0                                   Creed III
# 1                    Avatar: The Way of Water
# 2                 The Super Mario Bros. Movie
# 3                                   Supercell
# 4                                Cocaine Bear
# ...                                       ...
# 5086                            The Love Guru
# 5087                        The Lady Vanishes
# 5088                       20th Century Women
# 5089  Delta Force 2: The Colombian Connection
# 5090                         The Russia House
#
#                                                overview     budget_x  \
# 0     After dominating the boxing world, Adonis Cree...   75000000.0
# 1     Set more than a decade after the events of the...  460000000.0
# 2     While working underground to fix a water main,...  100000000.0
# 3     Good-hearted teenager William always lived in ...   77000000.0
# 4     Inspired by a true story, an oddball group of ...   35000000.0
# ...                                                 ...          ...
# 5086  Born in America and raised in an Indian ashram...   62000000.0
# 5087  On a train headed for England a group of trave...  132000000.0
# 5088  In 1979 Santa Barbara, California, Dorothea Fi...    7000000.0
# 5089  When DEA agents are taken captive by a ruthles...    9145817.8
# 5090  Barley Scott Blair, a Lisbon-based editor of R...   21800000.0
#
#            revenue country                                          genre  \
# 0     2.716167e+08      AU                                  Drama, Action
# 1     2.316795e+09      AU             Science Fiction, Adventure, Action
# 2     7.244590e+08      AU  Animation, Adventure, Family, Fantasy, Comedy
# 3     3.409420e+08      US                                         Action
# 4     8.000000e+07      AU                        Thriller, Comedy, Crime
# ...            ...     ...                                            ...
# 5086  4.015902e+07      AU                                Comedy, Romance
# 5087  5.637564e+08      GB                      Mystery, Thriller, Comedy
# 5088  9.353729e+06      US                                          Drama
# 5089  6.698361e+06      US                                         Action
# 5090  2.299799e+07      US                       Drama, Thriller, Romance
#
#            date_x  year_x      tconst titleType  \
# 0     03/02/2023     2023  tt11145118     movie
# 1     12/15/2022     2022   tt1630029     movie
# 2     04/05/2023     2023   tt6718170     movie
# 3     03/17/2023     2023  tt10559102     movie
# 4     02/23/2023     2023  tt14209916     movie
# ...           ...     ...         ...       ...
# 5086  07/10/2008     2008   tt0811138     movie
# 5087  10/07/1938     1938   tt0030341     movie
# 5088  12/28/2016     2016   tt4385888     movie
# 5089  08/24/1990     1990   tt0099399     movie
# 5090  12/21/1990     1990   tt0100530     movie
#
#                                  primaryTitle  \
# 0                                   Creed III
# 1                    Avatar: The Way of Water
# 2                 The Super Mario Bros. Movie
# 3                                   Supercell
# 4                                Cocaine Bear
# ...                                       ...
# 5086                            The Love Guru
# 5087                        The Lady Vanishes
# 5088                       20th Century Women
# 5089  Delta Force 2: The Colombian Connection
# 5090                         The Russia House
#
#                                 originalTitle  isAdult  startYear endYear  \
# 0                                   Creed III        0       2023      \N
# 1                    Avatar: The Way of Water        0       2022      \N
# 2                 The Super Mario Bros. Movie        0       2023      \N
# 3                                   Supercell        0       2023      \N
# 4                                Cocaine Bear        0       2023      \N
# ...                                       ...      ...        ...     ...
# 5086                            The Love Guru        0       2008      \N
# 5087                        The Lady Vanishes        0       1938      \N
# 5088                       20th Century Women        0       2016      \N
# 5089  Delta Force 2: The Colombian Connection        0       1990      \N
# 5090                         The Russia House        0       1990      \N
#
#      runtimeMinutes                      genres  averageRating  numVotes
# 0               116          Action,Drama,Sport            6.7     98374
# 1               192    Action,Adventure,Fantasy            7.5    523442
# 2                92  Adventure,Animation,Comedy            7.0    258549
# 3               100      Action,Adventure,Drama            4.4      3555
# 4                95       Comedy,Crime,Thriller            5.9    116631
# ...             ...                         ...            ...       ...
# 5086             87        Comedy,Romance,Sport            3.8     55695
# 5087             96            Mystery,Thriller            7.7     58711
# 5088            119                Comedy,Drama            7.3     50706
# 5089            111      Action,Adventure,Crime            4.9      8426
# 5090            123      Drama,Romance,Thriller            6.1     18469
#
# [5091 rows x 19 columns]
# 5091

# %%
duplicate_tconsts = df[df.duplicated('tconst', keep=False)]
display(duplicate_tconsts)
# Out:
#                  orig_title  \
# 64                   Scream
# 65                   Scream
# 114           The Lost City
# 115           The Lost City
# 141            The Avengers
# ...                     ...
# 5077  The Birth of a Nation
# 5078  The Birth of a Nation
# 5086              Pinocchio
# 5087              Pinocchio
# 5088              Pinocchio
#
#                                                overview     budget_x  \
# 64    Twenty-five years after a streak of brutal mur...   24000000.0
# 65    Twenty-five years after a streak of brutal mur...   15000000.0
# 114   Reclusive author Loretta Sage writes about exo...   74000000.0
# 115   Reclusive author Loretta Sage writes about exo...    9600000.0
# 141   When an unexpected enemy emerges and threatens...  225000000.0
# ...                                                 ...          ...
# 5077  Two families, abolitionist Northerners the Sto...   10000000.0
# 5078  Two families, abolitionist Northerners the Sto...     110000.0
# 5086  Roberto Benigni adapts the classic children's ...   45000000.0
# 5087  Roberto Benigni adapts the classic children's ...   13200000.0
# 5088  Roberto Benigni adapts the classic children's ...    2289247.0
#
#            revenue country                               genre       date_x  \
# 64    1.388748e+08      AU           Horror, Mystery, Thriller  01/13/2022
# 65    1.730466e+08      AU           Horror, Mystery, Thriller  01/13/2022
# 114   1.829220e+08      AU           Action, Adventure, Comedy  03/30/2022
# 115   5.256839e+06      AU           Action, Adventure, Comedy  03/30/2022
# 141   1.515100e+09      AU  Science Fiction, Action, Adventure  04/25/2012
# ...            ...     ...                                 ...          ...
# 5077  1.689101e+07      US                 Drama, History, War  02/08/1915
# 5078  1.100000e+07      US                 Drama, History, War  02/08/1915
# 5086  3.168181e+07      IT             Comedy, Family, Fantasy  10/11/2002
# 5087  3.036038e+07      IT             Comedy, Family, Fantasy  10/11/2002
# 5088  8.430000e+07      IT             Comedy, Family, Fantasy  10/11/2002
#
#       year_x      tconst titleType           primaryTitle  \
# 64      2022  tt11245972     movie                 Scream
# 65      2022  tt11245972     movie                 Scream
# 114     2022  tt13320622     movie          The Lost City
# 115     2022  tt13320622     movie          The Lost City
# 141     2012   tt0848228     movie           The Avengers
# ...      ...         ...       ...                    ...
# 5077    1915   tt0004972     movie  The Birth of a Nation
# 5078    1915   tt0004972     movie  The Birth of a Nation
# 5086    2002   tt0255477     movie              Pinocchio
# 5087    2002   tt0255477     movie              Pinocchio
# 5088    2002   tt0255477     movie              Pinocchio
#
#               originalTitle  isAdult  startYear endYear runtimeMinutes  \
# 64                   Scream        0       2022      \N            114
# 65                   Scream        0       2022      \N            114
# 114           The Lost City        0       2022      \N            112
# 115           The Lost City        0       2022      \N            112
# 141            The Avengers        0       2012      \N            143
# ...                     ...      ...        ...     ...            ...
# 5077  The Birth of a Nation        0       1915      \N            195
# 5078  The Birth of a Nation        0       1915      \N            195
# 5086              Pinocchio        0       2002      \N            108
# 5087              Pinocchio        0       2002      \N            108
# 5088              Pinocchio        0       2002      \N            108
#
#                        genres  averageRating  numVotes
# 64    Horror,Mystery,Thriller            6.3    169978
# 65    Horror,Mystery,Thriller            6.3    169978
# 114   Action,Adventure,Comedy            6.1    167659
# 115   Action,Adventure,Comedy            6.1    167659
# 141             Action,Sci-Fi            8.0   1492672
# ...                       ...            ...       ...
# 5077                Drama,War            6.1     27076
# 5078                Drama,War            6.1     27076
# 5086    Comedy,Family,Fantasy            4.3      8746
# 5087    Comedy,Family,Fantasy            4.3      8746
# 5088    Comedy,Family,Fantasy            4.3      8746
#
# [304 rows x 19 columns]

# %%
"""Merge csv files."""
# Load and filter title basics
title_basics = pd.read_csv('assets/title.basics.csv')
title_basics_filtered = title_basics.query('titleType in ["movie", "tvSeries"]')

# Load and process IMDb movies
imdb_movies = pd.read_csv('assets/imdb_movies.csv', usecols=['orig_title', 'overview', 'budget_x', 'revenue', 'country', 'genre', 'date_x'])
imdb_movies['year_x'] = pd.to_datetime(imdb_movies['date_x'], errors='coerce').dt.year.astype(str)

# Merge IMDb movies with filtered title basics
merged_data = pd.merge(
    imdb_movies, title_basics_filtered,
    left_on=['orig_title', 'year_x'],
    right_on=['originalTitle', 'startYear'],
    how='left'
)

# Load title ratings and merge with existing data
title_ratings = pd.read_csv('assets/title.ratings.csv')
merged_data = pd.merge(
    merged_data, title_ratings,
    on='tconst',
    how='left'
)

# Remove duplicates based on 'tconst'
merged_data = merged_data.drop_duplicates(subset='tconst')

merged_data['year_x'] = pd.to_numeric(merged_data['year_x'], errors='coerce')


country_avg_rating = merged_data.groupby('country')['averageRating'].mean().reset_index()

display(country_avg_rating)
# Out:
# /var/folders/cf/g9jbbqjx6zq_3xw0tdrvfhx40000gn/T/ipykernel_63036/2461870797.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_basics = pd.read_csv('assets/title.basics.csv')
#    country  averageRating
# 0       AR       6.166667
# 1       AU       6.415068
# 2       BE       5.633333
# 3       BR       4.966667
# 4       CA       5.730952
# 5       CH       5.950000
# 6       CL       4.925000
# 7       CN       6.033333
# 8       CO       4.800000
# 9       DE       5.616000
# 10      DK       5.866667
# 11      ES       5.579310
# 12      FI       4.850000
# 13      FR       6.089362
# 14      GB       5.965049
# 15      GR       5.850000
# 16      GT       5.150000
# 17      HK       5.600000
# 18      ID       6.014286
# 19      IE       5.866667
# 20      IN       5.700000
# 21      IT       5.679167
# 22      JP       4.400000
# 23      MU       5.400000
# 24      MX       5.362500
# 25      MY       4.900000
# 26      NL       6.012500
# 27      NO       4.850000
# 28      PE       6.000000
# 29      PH       5.102857
# 30      PL       5.333333
# 31      RU       4.866667
# 32      SE       6.100000
# 33      SG       5.950000
# 34      TR       5.666667
# 35      TW       3.000000
# 36      UA       5.100000
# 37      US       5.750000
# 38      ZA       5.133333

# %%
import pycountry

def iso2_to_country_name(iso2_code):
    try:
        # Convert ISO-2 to full country name using pycountry
        return pycountry.countries.get(alpha_2=iso2_code).name
    except AttributeError:
        return None  # Return None if the code is invalid or not found

# %%
merged_data['iso3_code'] = merged_data['country'].apply(iso2_to_country_name)

# Drop rows where conversion failed (invalid ISO-2 codes)
merged_data = merged_data.dropna(subset=['iso3_code'])

display(merged_data['iso3_code'].unique())
# Out:
# array(['Australia', 'United States', 'United Kingdom', 'Chile', 'Germany',
#        'Spain', 'France', 'Mexico', 'Guatemala', 'Brazil', 'South Africa',
#        'Netherlands', 'Finland', 'Indonesia', 'Denmark', 'Japan',
#        'Ireland', 'Belgium', 'Argentina', 'Philippines', 'Türkiye',
#        'Italy', 'Canada', 'Switzerland', 'China', 'Peru', 'Singapore',
#        'Poland', 'India', 'Greece', 'Russian Federation',
#        'Taiwan, Province of China', 'Malaysia', 'Mauritius', 'Norway',
#        'Ukraine', 'Hong Kong', 'Sweden', 'Colombia'], dtype=object)
